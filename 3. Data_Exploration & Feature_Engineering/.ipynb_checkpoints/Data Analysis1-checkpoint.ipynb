# %%
### Import Libraies

# %%
# import the different libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### Data_Exploration(Data Analysis)

# %%
Data = pd.read_csv('C:/Users/pooja/OneDrive/Desktop/We cloud/ML/Project #2/3. Data_Exploration & Feature_Engineering/Data_Analysis1.csv')

# %%
Data = Data.drop(['Unnamed: 0'],axis=1)

# %%
Data.Sales_Date = pd.to_datetime(Data.Sales_Date)

# %%
Data = Data.sort_values(['Sales_Date'])
Data
# Out:
#         Store_id Sales_Date  Temperature  MarkDown1  MarkDown2  MarkDown3  \
# 120124        13 2010-01-10        68.74       0.00        0.0       0.00
# 373364        40 2010-01-10        62.01       0.00        0.0       0.00
# 373365        40 2010-01-10        62.01       0.00        0.0       0.00
# 259245        27 2010-01-10        70.19       0.00        0.0       0.00
# 259244        27 2010-01-10        70.19       0.00        0.0       0.00
# ...          ...        ...          ...        ...        ...        ...
# 58844          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58845          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58846          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58848          6 2012-12-10        65.43    1905.34        0.0      13.83
# 380761        40 2012-12-10        47.35    1686.43        0.0      13.85
#
#         MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Store_Dept  \
# 120124       0.00       0.00  126.234600         7.795      False          14
# 373364       0.00       0.00  132.756800         5.287      False          74
# 373365       0.00       0.00  132.756800         5.287      False          79
# 259245       0.00       0.00  136.629757         8.021      False          98
# 259244       0.00       0.00  136.629757         8.021      False          97
# ...           ...        ...         ...           ...        ...         ...
# 58844      559.50    8706.87  225.005473         5.329      False          83
# 58845      559.50    8706.87  225.005473         5.329      False          85
# 58846      559.50    8706.87  225.005473         5.329      False          87
# 58848      559.50    8706.87  225.005473         5.329      False          91
# 380761     589.97    6365.02  138.911700         4.145      False           2
#
#         Weekly_Sales Store_Type  Store_Size  Sales_Month  Sales_Year  \
# 120124      20922.18          A      219622            1        2010
# 373364       9872.41          A      155083            1        2010
# 373365      10840.77          A      155083            1        2010
# 259245       9837.86          A      204184            1        2010
# 259244      19095.76          A      204184            1        2010
# ...              ...        ...         ...          ...         ...
# 58844        3690.95          A      202505           12        2012
# 58845        1645.71          A      202505           12        2012
# 58846       44915.71          A      202505           12        2012
# 58848       44775.89          A      202505           12        2012
# 380761      25868.29          A      155083           12        2012
#
#         Fuel_Price
# 120124       2.853
# 373364       2.717
# 373365       2.717
# 259245       2.840
# 259244       2.840
# ...            ...
# 58844        3.601
# 58845        3.601
# 58846        3.601
# 58848        3.601
# 380761       4.029
#
# [421570 rows x 18 columns]

# %%
#### Do some data exploration and data analysis using matplotlib and seaboarn

# %%
# 1. Let's see how many different Store_Type are available

# %%
X=Data.Store_Type.value_counts()
Store_Type_Labels = ["A","B","C"]

fig1, ax1 = plt.subplots()
ax1.pie(X,labels=Store_Type_Labels,autopct='%1.1f%%', shadow=True)
ax1.legend(title="Store Type:")

plt.show()

# %%
# loading dataset
data1 = Data.groupby(['Sales_Year','Sales_Month','Store_Dept'],as_index = False).Fuel_Price.mean()
data1 = pd.DataFrame(data1)
data1
# Out:
#       Sales_Year  Sales_Month  Store_Dept  Fuel_Price
# 0           2010            1           1    2.734333
# 1           2010            1           2    2.734333
# 2           2010            1           3    2.734333
# 3           2010            1           4    2.734333
# 4           2010            1           5    2.741279
# ...          ...          ...         ...         ...
# 2836        2012           12          95    3.896733
# 2837        2012           12          96    3.900564
# 2838        2012           12          97    3.903455
# 2839        2012           12          98    3.917857
# 2840        2012           12          99    3.829286
#
# [2841 rows x 4 columns]

# %%
# draw lineplot
# hue by sex
# style to hue
plt.figure(figsize=(15,6))
sns.lineplot(x="Sales_Year", y="Fuel_Price",data=data1,color="lightblue")
  
plt.show()

# %%
# draw lineplot
# hue by sex
# style to hue
plt.figure(figsize=(15,6))
sns.lineplot(x="Sales_Month", y="Fuel_Price",hue="Sales_Year",data=data1)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="Sales_Month", y="Fuel_Price",hue="Sales_Year",data=data1,color="lightblue")
#sns.color_palette("Set1")
plt.show()

# %%
# draw lineplot
# hue by sex
# style to hueValueError: Could not interpret input 'Sales_Month'

plt.figure(figsize=(15,6))
ax1 = sns.lineplot(x="Sales_Month", y='Fuel_Price',hue="Sales_Year",data=data1) 
ax2 = sns.barplot(x="Sales_Month", y='Fuel_Price',hue="Sales_Year",data=data1,color="lightblue")
ax2 = ax1.twinx()
plt.show()

# %%
data2 = Data.groupby(['IsHoliday','Sales_Month'],as_index = False).Fuel_Price.mean()
data2 = pd.DataFrame(data2)
data2
# draw lineplot
# hue by sex
# style to hue

plt.figure(figsize=(15,6))
sns.lineplot(x="Sales_Month", y="Fuel_Price",hue="IsHoliday",data=data2)

plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x="IsHoliday", y="Fuel_Price",hue="Store_Type",data=Data)
plt.ylim(3,3.5)
plt.show()

# %%
# draw lineplot
# hue by sex
# style to hue
Data['Year-Month'] = Data.Sales_Date.apply(lambda x: str(x)[:7])
data3 = Data.groupby(['Sales_Date','Year-Month'],as_index = False).Fuel_Price.mean()
data3 = pd.DataFrame(data3)
data3
# Out:
#     Sales_Date Year-Month  Fuel_Price
# 0   2010-01-10    2010-01    2.733064
# 1   2010-02-04    2010-02    2.825453
# 2   2010-02-07    2010-02    2.793190
# 3   2010-02-19    2010-02    2.673666
# 4   2010-02-26    2010-02    2.685642
# ..         ...        ...         ...
# 138 2012-10-08    2012-10    3.633858
# 139 2012-10-19    2012-10    3.878413
# 140 2012-10-26    2012-10    3.791086
# 141 2012-11-05    2012-11    3.870212
# 142 2012-12-10    2012-12    3.897425
#
# [143 rows x 3 columns]

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=data3, x='Year-Month', y="Fuel_Price")
plt.xticks(rotation = 60)
plt.show()

# %%
r=5
Data['Temperature_r'] = Data.sort_values(by=['Temperature']).Temperature.apply(lambda x : x - x %r)
Data
# Out:
#         Store_id Sales_Date  Temperature  MarkDown1  MarkDown2  MarkDown3  \
# 120124        13 2010-01-10        68.74       0.00        0.0       0.00
# 373364        40 2010-01-10        62.01       0.00        0.0       0.00
# 373365        40 2010-01-10        62.01       0.00        0.0       0.00
# 259245        27 2010-01-10        70.19       0.00        0.0       0.00
# 259244        27 2010-01-10        70.19       0.00        0.0       0.00
# ...          ...        ...          ...        ...        ...        ...
# 58844          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58845          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58846          6 2012-12-10        65.43    1905.34        0.0      13.83
# 58848          6 2012-12-10        65.43    1905.34        0.0      13.83
# 380761        40 2012-12-10        47.35    1686.43        0.0      13.85
#
#         MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Store_Dept  \
# 120124       0.00       0.00  126.234600         7.795      False          14
# 373364       0.00       0.00  132.756800         5.287      False          74
# 373365       0.00       0.00  132.756800         5.287      False          79
# 259245       0.00       0.00  136.629757         8.021      False          98
# 259244       0.00       0.00  136.629757         8.021      False          97
# ...           ...        ...         ...           ...        ...         ...
# 58844      559.50    8706.87  225.005473         5.329      False          83
# 58845      559.50    8706.87  225.005473         5.329      False          85
# 58846      559.50    8706.87  225.005473         5.329      False          87
# 58848      559.50    8706.87  225.005473         5.329      False          91
# 380761     589.97    6365.02  138.911700         4.145      False           2
#
#         Weekly_Sales Store_Type  Store_Size  Sales_Month  Sales_Year  \
# 120124      20922.18          A      219622            1        2010
# 373364       9872.41          A      155083            1        2010
# 373365      10840.77          A      155083            1        2010
# 259245       9837.86          A      204184            1        2010
# 259244      19095.76          A      204184            1        2010
# ...              ...        ...         ...          ...         ...
# 58844        3690.95          A      202505           12        2012
# 58845        1645.71          A      202505           12        2012
# 58846       44915.71          A      202505           12        2012
# 58848       44775.89          A      202505           12        2012
# 380761      25868.29          A      155083           12        2012
#
#         Fuel_Price Year-Month  Temperature_r
# 120124       2.853    2010-01           65.0
# 373364       2.717    2010-01           60.0
# 373365       2.717    2010-01           60.0
# 259245       2.840    2010-01           70.0
# 259244       2.840    2010-01           70.0
# ...            ...        ...            ...
# 58844        3.601    2012-12           65.0
# 58845        3.601    2012-12           65.0
# 58846        3.601    2012-12           65.0
# 58848        3.601    2012-12           65.0
# 380761       4.029    2012-12           45.0
#
# [421570 rows x 20 columns]

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=Data, x='Temperature_r', y="Fuel_Price",hue="IsHoliday",style = 'IsHoliday', markers = True, ci = 68)
plt.xticks(rotation = 60)
plt.show()

# %%
Date = Data[['Sales_Date', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']].plot(x = 'Sales_Date', subplots = True, figsize = (20,15))

# %%
plt.figure(figsize=(15,6))
sns.countplot(x="Sales_Year", hue="Sales_Month",data=Data)
#plt.ylim(3,3.5)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=Data, x='Year-Month', y="Weekly_Sales")
plt.xticks(rotation = 60)
plt.show()

# %%
Data.to_csv('C:/Users/pooja/OneDrive/Desktop/We cloud/ML/Project #2/3. Data_Exploration & Feature_Engineering/Data_Preprocessing1.csv')
