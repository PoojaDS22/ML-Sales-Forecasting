# %% [markdown]
# ### Import Libraries

# %%
# import the different libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import CSV

# %%
#open CSV file for analysis and feature engineering

# %%
Retail_Data_file = pd.read_csv('C:/Users/pooja/OneDrive/Desktop/We cloud/ML/Project #2/3. Data_Exploration & Feature_Engineering/RetailAnalysis_Data_Exploration_FE1.csv')

# %%
# check the retail data header
Retail_Data_file.head()
# Out:
#    Unnamed: 0  Store        Date  Temperature  Fuel_Price  MarkDown1  \
# 0           0      1  05/02/2010        42.31       2.572        0.0
# 1           1      1  05/02/2010        42.31       2.572        0.0
# 2           2      1  05/02/2010        42.31       2.572        0.0
# 3           3      1  05/02/2010        42.31       2.572        0.0
# 4           4      1  05/02/2010        42.31       2.572        0.0
#
#    MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0        0.0        0.0        0.0        0.0  211.096358         8.106
# 1        0.0        0.0        0.0        0.0  211.096358         8.106
# 2        0.0        0.0        0.0        0.0  211.096358         8.106
# 3        0.0        0.0        0.0        0.0  211.096358         8.106
# 4        0.0        0.0        0.0        0.0  211.096358         8.106
#
#    IsHoliday  Dept  Weekly_Sales Type    Size
# 0      False     1      24924.50    A  151315
# ...

# %% [markdown]
# ### Remove Irrelevant Columns

# %%
##first remove the unnamed column(auto generated column in pandas)
Retail_Data_file = Retail_Data_file.drop(['Unnamed: 0'],axis=1)

# %%
Retail_Data_file
# Out:
#         Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0           1  05/02/2010        42.31       2.572       0.00       0.00
# 1           1  05/02/2010        42.31       2.572       0.00       0.00
# 2           1  05/02/2010        42.31       2.572       0.00       0.00
# 3           1  05/02/2010        42.31       2.572       0.00       0.00
# 4           1  05/02/2010        42.31       2.572       0.00       0.00
# ...       ...         ...          ...         ...        ...        ...
# 421565     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421566     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421567     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421568     45  26/10/2012        58.85       3.882    4018.91      58.08
# 421569     45  26/10/2012        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# ...

# %% [markdown]
# ### Need some Feature Enginnering to Do more Accurate analysis

# %%
#to do more accurate analysis based on month and year
#need to create 2 more column month and year using the date column
Retail_Data_file['Sales_Month']=pd.DatetimeIndex(Retail_Data_file['Date']).month
Retail_Data_file['Sales_Year']=pd.DatetimeIndex(Retail_Data_file['Date']).year

# %%
Retail_Data_file.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  05/02/2010        42.31       2.572        0.0        0.0
# 1      1  05/02/2010        42.31       2.572        0.0        0.0
# 2      1  05/02/2010        42.31       2.572        0.0        0.0
# 3      1  05/02/2010        42.31       2.572        0.0        0.0
# 4      1  05/02/2010        42.31       2.572        0.0        0.0
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  Dept  \
# 0        0.0        0.0        0.0  211.096358         8.106      False     1
# 1        0.0        0.0        0.0  211.096358         8.106      False     2
# 2        0.0        0.0        0.0  211.096358         8.106      False     3
# 3        0.0        0.0        0.0  211.096358         8.106      False     4
# 4        0.0        0.0        0.0  211.096358         8.106      False     5
#
#    Weekly_Sales Type    Size  Sales_Month  Sales_Year
# ...

# %%
#rename column labels

# %%
Retail_Data_file=Retail_Data_file.rename(columns={"Store":"Store_id","Date":"Sales_Date","Type":"Store_Type","Dept":"Store_Dept","Size":"Store_Size"})

# %%
Retail_Data_file=Retail_Data_file[["Store_id","Sales_Date","Temperature","MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5","CPI","Unemployment","IsHoliday","Store_Dept","Weekly_Sales","Store_Type","Store_Size","Sales_Month","Sales_Year","Fuel_Price"]]

# %%
Retail_Data_file
# Out:
#         Store_id  Sales_Date  Temperature  MarkDown1  MarkDown2  MarkDown3  \
# 0              1  05/02/2010        42.31       0.00       0.00        0.0
# 1              1  05/02/2010        42.31       0.00       0.00        0.0
# 2              1  05/02/2010        42.31       0.00       0.00        0.0
# 3              1  05/02/2010        42.31       0.00       0.00        0.0
# 4              1  05/02/2010        42.31       0.00       0.00        0.0
# ...          ...         ...          ...        ...        ...        ...
# 421565        45  26/10/2012        58.85    4018.91      58.08      100.0
# 421566        45  26/10/2012        58.85    4018.91      58.08      100.0
# 421567        45  26/10/2012        58.85    4018.91      58.08      100.0
# 421568        45  26/10/2012        58.85    4018.91      58.08      100.0
# 421569        45  26/10/2012        58.85    4018.91      58.08      100.0
#
# ...

# %%
Retail_Data_file.to_csv('C:/Users/pooja/OneDrive/Desktop/We cloud/ML/Project #2/3. Data_Exploration & Feature_Engineering/Data_Analysis1.csv')
